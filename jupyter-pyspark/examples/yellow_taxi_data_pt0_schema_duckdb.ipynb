# %%
# Define the base URL pattern
base_url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{}.parquet"

# Define date range
start_date = "2009-01"
end_date = "2024-08"

# %%
! pip3 install duckdb
# Out:
# Requirement already satisfied: duckdb in /opt/conda/lib/python3.12/site-packages (1.1.3)

# %%
import duckdb

con = duckdb.connect()
con.install_extension("httpfs")
con.load_extension("httpfs")

# %%
import pandas as pd
import duckdb
import time
import logging

# Create a DuckDB connection
con = duckdb.connect()

# date range
dates = pd.date_range(start_date, end_date, freq="MS").strftime("%Y-%m").tolist()

# Generate the list of SQL commands
sql_commands = [
    f"SELECT * FROM parquet_schema('{base_url.format(date.replace('-', '-'))}')" for date in dates
]

def load_with_backoff(con, sql_command, max_retries=10, initial_delay=15, backoff_factor=2):
    """
    Load data using a SQL command with retry and backoff logic.

    Args:
        con (duckdb.DuckDBPyConnection): DuckDB connection object.
        sql_command (str): The SQL command to execute.
        max_retries (int): Maximum number of retries.
        initial_delay (int): Initial delay in seconds.
        backoff_factor (int): Factor by which the delay increases after each retry.

    Returns:
        pd.DataFrame: DataFrame containing the loaded data, or None if it failed.
    """
    delay = initial_delay
    for attempt in range(max_retries):
        try:
            print(f"Executing SQL: {sql_command} (Attempt {attempt + 1})...")
            return con.sql(sql_command).df()
        except Exception as e:
            if attempt < max_retries - 1:
                print(f"Failed to execute SQL, retrying in {delay} seconds... ({attempt + 1}/{max_retries})")
                time.sleep(delay)
                delay *= backoff_factor
            else:
                logging.error(f"Failed to execute SQL after {max_retries} retries: {e}")
    return None


# Load all SQL commands
dfs = [load_with_backoff(con, sql) for sql in sql_commands]

# Filter out None results
dfs = [df for df in dfs if df is not None]

# Concatenate all DataFrames into one
if dfs:
    final_df = pd.concat(dfs, ignore_index=True)
    print(f"Loaded {len(final_df)} rows from {len(dfs)} files.")
else:
    print("No data loaded.")

# Save to a single Parquet file (optional)
final_df.to_parquet("combined_tripdata_200901_to_202408.parquet")
# Out:
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet') (Attempt 1)...
# Failed to execute SQL, retrying in 15 seconds... (1/10)
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet') (Attempt 2)...
# Failed to execute SQL, retrying in 30 seconds... (2/10)
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet') (Attempt 3)...
# Failed to execute SQL, retrying in 60 seconds... (3/10)
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet') (Attempt 4)...
# Failed to execute SQL, retrying in 120 seconds... (4/10)
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet') (Attempt 5)...
# Failed to execute SQL, retrying in 240 seconds... (5/10)
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet') (Attempt 6)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-08.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-09.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-10.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-11.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-12.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-02.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-03.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-04.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-05.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-06.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-07.parquet') (Attempt 1)...
# Executing SQL: SELECT * FROM parquet_schema('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-08.parquet') (Attempt 1)...
# Loaded 3738 rows from 188 files.

# %%
final_df
# Out:
#                                               file_name  \
# 0     https://d37ci6vzurychx.cloudfront.net/trip-dat...
# 1     https://d37ci6vzurychx.cloudfront.net/trip-dat...
# 2     https://d37ci6vzurychx.cloudfront.net/trip-dat...
# 3     https://d37ci6vzurychx.cloudfront.net/trip-dat...
# 4     https://d37ci6vzurychx.cloudfront.net/trip-dat...
# ...                                                 ...
# 3733  https://d37ci6vzurychx.cloudfront.net/trip-dat...
# 3734  https://d37ci6vzurychx.cloudfront.net/trip-dat...
# 3735  https://d37ci6vzurychx.cloudfront.net/trip-dat...
# 3736  https://d37ci6vzurychx.cloudfront.net/trip-dat...
# 3737  https://d37ci6vzurychx.cloudfront.net/trip-dat...
#
#                        name        type type_length repetition_type  \
# 0                    schema        None        None        REQUIRED
# 1               vendor_name  BYTE_ARRAY        None        OPTIONAL
# 2      Trip_Pickup_DateTime  BYTE_ARRAY        None        OPTIONAL
# 3     Trip_Dropoff_DateTime  BYTE_ARRAY        None        OPTIONAL
# 4           Passenger_Count       INT64        None        OPTIONAL
# ...                     ...         ...         ...             ...
# 3733           tolls_amount      DOUBLE        None        OPTIONAL
# 3734  improvement_surcharge      DOUBLE        None        OPTIONAL
# 3735           total_amount      DOUBLE        None        OPTIONAL
# 3736   congestion_surcharge      DOUBLE        None        OPTIONAL
# 3737            Airport_fee      DOUBLE        None        OPTIONAL
#
#       num_children converted_type  scale  precision  field_id  logical_type
# 0             18.0           None    NaN        NaN       NaN          None
# 1              NaN           UTF8    NaN        NaN       NaN  StringType()
# 2              NaN           UTF8    NaN        NaN       NaN  StringType()
# 3              NaN           UTF8    NaN        NaN       NaN  StringType()
# 4              NaN           None    NaN        NaN       NaN          None
# ...            ...            ...    ...        ...       ...           ...
# 3733           NaN           None    NaN        NaN       NaN          None
# 3734           NaN           None    NaN        NaN       NaN          None
# 3735           NaN           None    NaN        NaN       NaN          None
# 3736           NaN           None    NaN        NaN       NaN          None
# 3737           NaN           None    NaN        NaN       NaN          None
#
# [3738 rows x 11 columns]
