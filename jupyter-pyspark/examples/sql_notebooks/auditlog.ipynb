# %% [markdown]
# # Trino Connection

# %%
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
# %load_ext sql

# %%
# %sql trino://admin@${DOCKER_HOST_OR_IP}:8443/vast  --connection_arguments '{"http_scheme":"https", "verify": false}'
# Out:
# Connecting to 'trino://admin@10.143.11.241:8443/vast'

# %%
# %%sql
#
# SELECT
#     cluster_name,
#     cnode_name,
#     time,
#     client_ip,
#     cluster_vip,
#     tenant,
#     protocol,
#     rpc_type,
#     --path, -- this field causes a jupyter error
#     view_path,
#     --name, -- this field causes a jupyter error
#     login_name,
#     uid,
#     sid,
#     s3_access_keys,
#     status,
#     nfs3_required_permissions,
#     nfs3_granted_permissions,
#     nfs_link_name,
#     nfs_link_path,
#     rename_path,
#     rename_name,
#     nfs_rpc_sub_types,
#     nfs_symlink,
#     nfs4_required_access,
#     nfs4_granted_access,
#     nfs4_ftype,
#     s3_used_access_key,
#     s3_request_id,
#     connection_type,
#     s3_bucket_name,
#     s3_multipart_upload_id,
#     s3_version_id,
#     s3_version_phandle,
#     s3_source_object,
#     smb_ads_name,
#     smb_create_action,
#     smb_create_option,
#     smb_create_disposition,
#     smb_delete_on_close,
#     smb_info_type,
#     smb_info_class,
#     smb_rename_struct,
#     num_ops,
#     num_bytes,
#     time_str
# FROM
#     "vast-audit-log-bucket|vast_audit_log_schema".vast_audit_log_table
# LIMIT 10
# Out:
# Running query in 'trino://admin@10.143.11.241:8443/vast'
# +---------------+------------+----------------------------+----------------+---------------+---------+----------+------------+---------------+-------------------------------+------+------+--------------------------------------+---------+---------------------------+--------------------------+---------------+---------------+-------------+-------------+-------------------+-------------+----------------------+---------------------+------------+----------------------+-----------------+-----------------+----------------+------------------------+---------------+--------------------+------------------+--------------+-------------------+-------------------+------------------------+---------------------+---------------+----------------+-------------------+---------+-----------+--------------------------+
# |  cluster_name | cnode_name |            time            |   client_ip    |  cluster_vip  |  tenant | protocol |  rpc_type  |   view_path   |           login_name          | uid  | sid  |            s3_access_keys            |  status | nfs3_required_permissions | nfs3_granted_permissions | nfs_link_name | nfs_link_path | rename_path | rename_name | nfs_rpc_sub_types | nfs_symlink | nfs4_required_access | nfs4_granted_access | nfs4_ftype |  s3_used_access_key  |  s3_request_id  | connection_type | s3_bucket_name | s3_multipart_upload_id | s3_version_id | s3_version_phandle | s3_source_object | smb_ads_name | smb_create_action | smb_create_option | smb_create_disposition | smb_delete_on_close | smb_info_type | smb_info_class | smb_rename_struct | num_ops | num_bytes |         time_str         |
# +---------------+------------+----------------------------+----------------+---------------+---------+----------+------------+---------------+-------------------------------+------+------+--------------------------------------+---------+---------------------------+--------------------------+---------------+---------------+-------------+-------------+-------------------+-------------+----------------------+---------------------+------------+----------------------+-----------------+-----------------+----------------+------------------------+---------------+--------------------+------------------+--------------+-------------------+-------------------+------------------------+---------------------+---------------+----------------+-------------------+---------+-----------+--------------------------+
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:57.931993 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493272701709371 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |   49216   | 2024-11-22T12:22:57.931Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:58.020990 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493272701709373 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |  5358905  | 2024-11-22T12:22:58.020Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:58.176350 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493272701709380 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |  7538203  | 2024-11-22T12:22:58.176Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:58.288606 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493272701709389 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |  7886160  | 2024-11-22T12:22:58.288Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:57.930906 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493822458649759 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |   49216   | 2024-11-22T12:22:57.930Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:57.968070 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493822458649761 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |  6098686  | 2024-11-22T12:22:57.968Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:58.004935 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493822458649768 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |  8117111  | 2024-11-22T12:22:58.004Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:58.051434 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493822458649777 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |  8134610  | 2024-11-22T12:22:58.051Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:58.089868 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493822458649786 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |  7989082  | 2024-11-22T12:22:58.089Z |
# | selab-var-204 | cnode-3-13 | 2024-11-22 12:22:58.150984 | 172.200.12.241 | 172.200.204.2 | default |    S3    | GET_OBJECT | /csnow-bucket | chris.snow@selab.vastdata.com | 5102 | None | ['Y5101AQQTB1PUAEKQXN5', '', '', ''] | Success |            None           |           None           |      None     |      None     |     None    |     None    |        None       |     None    |         None         |         None        |    None    | Y5101AQQTB1PUAEKQXN5 | 493822458649795 |       HTTP      |  csnow-bucket  |          None          |       -1      |        None        |       None       |     None     |        None       |        None       |          None          |         None        |      None     |      None      |        None       |    1    |  7414489  | 2024-11-22T12:22:58.150Z |
# +---------------+------------+----------------------------+----------------+---------------+---------+----------+------------+---------------+-------------------------------+------+------+--------------------------------------+---------+---------------------------+--------------------------+---------------+---------------+-------------+-------------+-------------------+-------------+----------------------+---------------------+------------+----------------------+-----------------+-----------------+----------------+------------------------+---------------+--------------------+------------------+--------------+-------------------+-------------------+------------------------+---------------------+---------------+----------------+-------------------+---------+-----------+--------------------------+
# Truncated to displaylimit of 10.
