# %% [markdown]
# # Query Catalog with Trino Connection
#
# Also see:
# - https://grafana.com/grafana/dashboards/21760-vast-catalog-dashboard/

# %%
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
# %load_ext sql

# %%
# %sql trino://admin@${DOCKER_HOST_OR_IP}:8443/vast  --connection_arguments '{"http_scheme":"https", "verify": false}'
# Out:
# Connecting to 'trino://admin@10.143.11.241:8443/vast'

# %%
# %%sql
#
# -- Jupysql throws an error when using `SELECT *` so manually specify columns
#
# SELECT
#         --phandle, -- phandle causes a jupyter issue
#         creation_time,
#         uid,
#         owner_sid,
#         owner_name,
#         gid,
#         group_owner_sid,
#         group_owner_name,
#         atime,
#         mtime,
#         ctime,
#         nlinks,
#         element_type,
#         size,
#         used,
#         tenant_id,
#         name,
#         extension,
#         parent_path,
#         symlink_path,
#         major_device,
#         minor_device,
#         s3_locks_retention,
#         nfs_mode_bits,
#         name_aces_exist,
#         s3_locks_legal_hold,
#         user_tags_count,
#         user_metadata,
#         user_tags,
#         login_name,
#         search_path,
#         metadata_md
# FROM
#     "vast-big-catalog-bucket|vast_big_catalog_schema".vast_big_catalog_table
# LIMIT 10
# Out:
# Running query in 'trino://admin@10.143.11.241:8443/vast'
# +----------------------------+------+------------------------------------------------+------------+------+-----------------+------------------+----------------------------+----------------------------+----------------------------+--------+--------------+------+------+-----------+-----------------+-----------+----------------------------------------------------------------------------+--------------+--------------+--------------+--------------------+---------------+-----------------+---------------------+-----------------+---------------+-----------+-----------------------------+----------------------------------------------------------------------------+-------------+
# |       creation_time        | uid  |                   owner_sid                    | owner_name | gid  | group_owner_sid | group_owner_name |           atime            |           mtime            |           ctime            | nlinks | element_type | size | used | tenant_id |       name      | extension |                                parent_path                                 | symlink_path | major_device | minor_device | s3_locks_retention | nfs_mode_bits | name_aces_exist | s3_locks_legal_hold | user_tags_count | user_metadata | user_tags |          login_name         |                                search_path                                 | metadata_md |
# +----------------------------+------+------------------------------------------------+------------+------+-----------------+------------------+----------------------------+----------------------------+----------------------------+--------+--------------+------+------+-----------+-----------------+-----------+----------------------------------------------------------------------------+--------------+--------------+--------------+--------------------+---------------+-----------------+---------------------+-----------------+---------------+-----------+-----------------------------+----------------------------------------------------------------------------+-------------+
# | 2024-11-26 02:31:29.310476 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:31:09.303217 | 2024-11-26 02:31:09.303217 | 2024-11-26 02:31:09.303217 |   1    |     FILE     | 4096 | 4096 |     -1    | file_794293.bin |    bin    |            /james/noatime/1million/se-var-cb3-c1/subfolder_19/             |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |            /james/noatime/1million/se-var-cb3-c1/subfolder_19/             |     None    |
# | 2024-11-26 02:23:45.506225 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:23:38.372290 | 2024-11-26 02:23:38.372290 | 2024-11-26 02:23:38.372290 |   1    |     FILE     | 4096 | 4096 |     -1    | file_696736.bin |    bin    |         /james/noatime-audit/1million/se-var-cb3-c4/subfolder_16/          |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |         /james/noatime-audit/1million/se-var-cb3-c4/subfolder_16/          |     None    |
# | 2024-11-26 02:24:56.166129 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:24:49.030981 | 2024-11-26 02:24:49.030981 | 2024-11-26 02:24:49.030981 |   1    |     FILE     | 4096 | 4096 |     -1    | file_537218.bin |    bin    | /james/noatime-audit/1million/se-var-cb2-c2.var.vastdata.com/subfolder_12/ |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com | /james/noatime-audit/1million/se-var-cb2-c2.var.vastdata.com/subfolder_12/ |     None    |
# | 2024-11-26 02:19:21.003301 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:19:21.017730 | 2024-11-26 02:19:21.017730 | 2024-11-26 02:19:21.017730 |   1    |     FILE     | 4096 | 4096 |     -1    | file_844704.bin |    bin    |         /james/noatime-audit/1million/se-var-cb1-c4/subfolder_20/          |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |         /james/noatime-audit/1million/se-var-cb1-c4/subfolder_20/          |     None    |
# | 2024-11-26 02:19:00.239450 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:19:00.241624 | 2024-11-26 02:19:00.241624 | 2024-11-26 02:19:00.241624 |   1    |     FILE     | 4096 | 4096 |     -1    | file_593635.bin |    bin    |         /james/noatime-audit/1million/se-var-cb1-c4/subfolder_14/          |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |         /james/noatime-audit/1million/se-var-cb1-c4/subfolder_14/          |     None    |
# | 2024-11-26 02:31:01.129145 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:31:17.680659 | 2024-11-26 02:31:17.680659 | 2024-11-26 02:31:17.680659 |   1    |     FILE     | 4096 | 4096 |     -1    |  file_43017.bin |    bin    |             /james/noatime/1million/se-var-cb3-c1/subfolder_1/             |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |             /james/noatime/1million/se-var-cb3-c1/subfolder_1/             |     None    |
# | 2024-11-26 02:21:41.765701 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:21:28.914315 | 2024-11-26 02:21:28.914315 | 2024-11-26 02:21:28.914315 |   1    |     FILE     | 4096 | 4096 |     -1    | file_315412.bin |    bin    | /james/noatime-audit/1million/se-var-cb2-c2.var.vastdata.com/subfolder_7/  |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com | /james/noatime-audit/1million/se-var-cb2-c2.var.vastdata.com/subfolder_7/  |     None    |
# | 2024-11-26 02:22:12.289609 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:22:08.832513 | 2024-11-26 02:22:08.832513 | 2024-11-26 02:22:08.832513 |   1    |     FILE     | 4096 | 4096 |     -1    | file_728554.bin |    bin    |         /james/noatime-audit/1million/se-var-cb3-c3/subfolder_17/          |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |         /james/noatime-audit/1million/se-var-cb3-c3/subfolder_17/          |     None    |
# | 2024-11-26 02:20:40.510142 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:20:33.379004 | 2024-11-26 02:20:33.379004 | 2024-11-26 02:20:33.379004 |   1    |     FILE     | 4096 | 4096 |     -1    |  file_14799.bin |    bin    |          /james/noatime-audit/1million/se-var-cb3-c3/subfolder_0/          |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |          /james/noatime-audit/1million/se-var-cb3-c3/subfolder_0/          |     None    |
# | 2024-11-26 02:31:15.291694 | 1000 | S-1-5-21-2499193476-3784937457-2917841277-1114 |  vastdata  | 1001 |       None      |       None       | 2024-11-26 02:31:22.438683 | 2024-11-26 02:31:22.438683 | 2024-11-26 02:31:22.438683 |   1    |     FILE     | 4096 | 4096 |     -1    | file_334854.bin |    bin    |    /james/noatime/1million/se-var-cb2-c2.var.vastdata.com/subfolder_8/     |     None     |     None     |     None     |        None        |      436      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |    /james/noatime/1million/se-var-cb2-c2.var.vastdata.com/subfolder_8/     |     None    |
# +----------------------------+------+------------------------------------------------+------------+------+-----------------+------------------+----------------------------+----------------------------+----------------------------+--------+--------------+------+------+-----------+-----------------+-----------+----------------------------------------------------------------------------+--------------+--------------+--------------+--------------------+---------------+-----------------+---------------------+-----------------+---------------+-----------+-----------------------------+----------------------------------------------------------------------------+-------------+
# Truncated to displaylimit of 10.
