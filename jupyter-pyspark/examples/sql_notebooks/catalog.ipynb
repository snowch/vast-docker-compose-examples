# %% [markdown]
# # Trino Connection

# %%
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql trino://admin@${DOCKER_HOST_OR_IP}:8443/vast  --connection_arguments '{"http_scheme":"https", "verify": false}'

# %%
# %%sql
#
# SELECT
#     --phandle, -- phandle causes a jupyter issue
#     creation_time,
#     uid,
#     owner_sid,
#     owner_name,
#     gid,
#     group_owner_sid,
#     group_owner_name,
#     atime,
#     mtime,
#     ctime,
#     nlinks,
#     element_type,
#     size,
#     used,
#     tenant_id,
#     name,
#     extension,
#     parent_path,
#     symlink_path,
#     major_device,
#     minor_device,
#     s3_locks_retention,
#     nfs_mode_bits,
#     name_aces_exist,
#     s3_locks_legal_hold,
#     user_tags_count,
#     user_metadata,
#     user_tags,
#     login_name,
#     search_path,
#     metadata_md
# FROM
#     "vast-big-catalog-bucket|vast_big_catalog_schema".vast_big_catalog_table
# LIMIT 10
# Out:
# Running query in 'trino://admin@10.143.11.241:8443/vast'
# +----------------------------+-------+-------------------------------------------------------+----------------+------+-----------------+------------------+----------------------------+----------------------------+----------------------------+--------+--------------+-----------+-----------+-----------+-------------------+-----------+-------------------------------------------------------------+--------------+--------------+--------------+--------------------+---------------+-----------------+---------------------+-----------------+---------------+-----------+-----------------------------+-------------------------------------------------------------+-------------+
# |       creation_time        |  uid  |                       owner_sid                       |   owner_name   | gid  | group_owner_sid | group_owner_name |           atime            |           mtime            |           ctime            | nlinks | element_type |    size   |    used   | tenant_id |        name       | extension |                         parent_path                         | symlink_path | major_device | minor_device | s3_locks_retention | nfs_mode_bits | name_aces_exist | s3_locks_legal_hold | user_tags_count | user_metadata | user_tags |          login_name         |                         search_path                         | metadata_md |
# +----------------------------+-------+-------------------------------------------------------+----------------+------+-----------------+------------------+----------------------------+----------------------------+----------------------------+--------+--------------+-----------+-----------+-----------+-------------------+-----------+-------------------------------------------------------------+--------------+--------------+--------------+--------------------+---------------+-----------------+---------------------+-----------------+---------------+-----------+-----------------------------+-------------------------------------------------------------+-------------+
# | 2024-11-12 01:02:32.400483 |  1000 |     S-1-5-21-2499193476-3784937457-2917841277-1114    |    vastdata    | 1001 |       None      |       None       | 2024-11-12 01:03:40.852234 | 2024-11-12 01:03:40.852234 | 2024-11-12 01:03:40.852234 |   1    |     FILE     | 104857600 | 104857600 |     -1    |     flush.9.14    |     14    |                           /cpeel/                           |     None     |     None     |     None     |        None        |      420      |      False      |         None        |       None      |      None     |    None   | vastdata@selab.vastdata.com |                           /cpeel/                           |     None    |
# | 2024-11-12 18:38:28.548413 | 55572 | S-1-111-734251340-2489201226-3423371408-1724060672-32 | robM-demo-flow | 5745 |       None      |       None       | 2020-09-17 04:31:20.608393 | 2019-10-29 07:28:40.359891 | 2024-11-12 18:38:28.550916 |   1    |     FILE     |   16144   |   16144   |     -1    |    hub-band.tar   |    tar    |            /scratch/home/robM-demo-flow/securing/           |     None     |     None     |     None     |        None        |      420      |      False      |         None        |       None      |      None     |    None   |        robM-demo-flow       |            /scratch/home/robM-demo-flow/securing/           |     None    |
# | 2024-11-12 18:38:22.224256 | 55572 | S-1-111-734251340-2489201226-3423371408-1724060672-32 | robM-demo-flow | 5271 |       None      |       None       | 2022-06-17 14:24:23.814783 | 2017-03-09 00:09:07.323861 | 2024-11-12 18:38:22.237864 |   1    |     FILE     |   78608   |   78608   |     -1    |   scabellum.xls   |    xls    |        /scratch/home/robM-demo-flow/securing/drupes/        |     None     |     None     |     None     |        None        |      420      |      False      |         None        |       None      |      None     |    None   |        robM-demo-flow       |        /scratch/home/robM-demo-flow/securing/drupes/        |     None    |
# | 2024-11-12 18:38:27.991504 | 55572 | S-1-111-734251340-2489201226-3423371408-1724060672-32 | robM-demo-flow | 5535 |       None      |       None       | 2022-04-11 04:37:27.483239 | 2021-01-26 12:40:19.665786 | 2024-11-12 18:38:27.995675 |   1    |     FILE     |  1320720  |  1320720  |     -1    |      SYC.html     |    html   |            /scratch/home/robM-demo-flow/securing/           |     None     |     None     |     None     |        None        |      420      |      False      |         None        |       None      |      None     |    None   |        robM-demo-flow       |            /scratch/home/robM-demo-flow/securing/           |     None    |
# | 2024-11-12 18:38:28.720306 | 55572 | S-1-111-734251340-2489201226-3423371408-1724060672-32 | robM-demo-flow | 5875 |       None      |       None       | 2022-02-09 02:33:23.611434 | 2019-06-20 21:47:17.245109 | 2024-11-12 18:38:28.722884 |   1    |     FILE     |   221968  |   221968  |     -1    |     jenny.jpg     |    jpg    | /scratch/home/robM-demo-flow/squamosoparietal/outmanoeuvre/ |     None     |     None     |     None     |        None        |      420      |      False      |         None        |       None      |      None     |    None   |        robM-demo-flow       | /scratch/home/robM-demo-flow/squamosoparietal/outmanoeuvre/ |     None    |
# +----------------------------+-------+-------------------------------------------------------+----------------+------+-----------------+------------------+----------------------------+----------------------------+----------------------------+--------+--------------+-----------+-----------+-----------+-------------------+-----------+-------------------------------------------------------------+--------------+--------------+--------------+--------------------+---------------+-----------------+---------------------+-----------------+---------------+-----------+-----------------------------+-------------------------------------------------------------+-------------+
# Truncated to displaylimit of 10.
