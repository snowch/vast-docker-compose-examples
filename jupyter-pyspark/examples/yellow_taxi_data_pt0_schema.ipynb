# %%
# Base URL and dynamic iteration range
base_url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year}-{month}.parquet"
start_year, start_month = 2009, 1
end_year, end_month = 2024, 8

# %%
import pyarrow.parquet as pq
import requests
from io import BytesIO
from datetime import datetime
import pandas as pd
import time

def get_parquet_schema_with_dynamic_range(url, max_retries=15, backoff_factor=2):
    retries = 0
    session = requests.Session()  # Create the session outside the loop so it can be reused

    while retries <= max_retries:
        try:
            # Get the file size using a HEAD request
            head_response = session.head(url)  # Use session for the head request
            if head_response.status_code == 403:
                raise requests.exceptions.RequestException("Rate limit hit (403).")

            if head_response.status_code != 200:
                raise Exception(f"Failed to access {url}: {head_response.status_code} {head_response.reason}")

            file_size = int(head_response.headers.get('Content-Length', 0))
            if file_size == 0:
                raise Exception(f"Unable to retrieve file size for {url}")

            # Fetch the last 64 KB or up to the file size (whichever is smaller)
            range_size = min(65536, file_size)
            headers = {'Range': f'bytes=-{range_size}'}
            response = session.get(url, headers=headers)  # Use session for the GET request
            response.raise_for_status()

            # Read footer and parse schema
            footer = BytesIO(response.content)
            parquet_file = pq.ParquetFile(footer)
            schema = parquet_file.schema
            return schema

        except requests.exceptions.RequestException as e:
            # Handle rate-limit or other request errors
            if retries < max_retries:
                wait_time = backoff_factor ** retries
                print(f"Rate limit or error for {url}. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
                retries += 1
                # Create a new session on retry
                print("Creating a new session...")
                session = requests.Session()  # Recreate the session on retry
            else:
                raise Exception(f"Max retries exceeded for {url}: {e}")

# %%
def main():

    # List to store schema details for concatenation
    schema_records = []

    for year in range(start_year, end_year + 1):
        for month in range(1, 13):
            if (year == end_year and month > end_month):
                break

            # Format the URL dynamically
            month_str = f"{month:02d}"
            url = base_url.format(year=year, month=month_str)
            print(f"Fetching schema for {url}...")

            try:
                # Get schema for the current file
                schema = get_parquet_schema_with_dynamic_range(url)
                # Add schema details to the records list
                for i, n in enumerate(schema.names):
                    col = schema.column(i)
                    schema_records.append(
                        {
                            "YearMonth": f"{year}{month_str}",
                            "Name": n,
                            "Type": col.physical_type
                        }
                    )
            except Exception as e:
                print(f"Error fetching schema for {url}: {e}")
                raise e

    # Convert the list of records to a DataFrame
    schema_df = pd.DataFrame(schema_records)

    return schema_df

schema_df = main()
# Out:
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet. Retrying in 1 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet. Retrying in 2 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet. Retrying in 4 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet. Retrying in 8 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet. Retrying in 16 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet. Retrying in 32 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-01.parquet. Retrying in 64 seconds...
# Creating a new session...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2009-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2010-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2011-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2012-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2013-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2014-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 1 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 2 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 4 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 8 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 16 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 32 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 64 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 128 seconds...
# Creating a new session...
# Rate limit or error for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet. Retrying in 256 seconds...
# Creating a new session...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-08.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-09.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-10.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-11.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-12.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-02.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-03.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-04.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-05.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-06.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-07.parquet...
# Fetching schema for https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-08.parquet...

# %%
schema_df
# Out:
#      YearMonth                   Name        Type
# 0       200901            vendor_name  BYTE_ARRAY
# 1       200901   Trip_Pickup_DateTime  BYTE_ARRAY
# 2       200901  Trip_Dropoff_DateTime  BYTE_ARRAY
# 3       200901        Passenger_Count       INT64
# 4       200901          Trip_Distance      DOUBLE
# ...        ...                    ...         ...
# 3545    202408           tolls_amount      DOUBLE
# 3546    202408  improvement_surcharge      DOUBLE
# 3547    202408           total_amount      DOUBLE
# 3548    202408   congestion_surcharge      DOUBLE
# 3549    202408            Airport_fee      DOUBLE
#
# [3550 rows x 3 columns]

# %%
# Sort by YearMonth to ensure chronological order
schema_df['YearMonth'] = schema_df['YearMonth'].astype(str)
schema_df = schema_df.sort_values(by=['YearMonth']).reset_index(drop=True)

# Function to print schema evolution
def print_schema_evolution(df):
    previous_schema = pd.DataFrame(columns=['Name', 'Type'])
    
    for year_month in df['YearMonth'].unique():
        # Filter the schema for the current YearMonth
        current_schema = df[df['YearMonth'] == year_month]
        
        # Print the schema evolution compared to the previous schema
        print(f"\nSchema changes for {year_month}:")
        
        if not previous_schema.empty:
            # Compare new fields (present in current but not in previous)
            new_fields = current_schema[~current_schema['Name'].isin(previous_schema['Name'])]
            if not new_fields.empty:
                print(f"New fields added: \n{new_fields[['Name', 'Type']]}")
            
            # Compare removed fields (present in previous but not in current)
            removed_fields = previous_schema[~previous_schema['Name'].isin(current_schema['Name'])]
            if not removed_fields.empty:
                print(f"Fields removed: \n{removed_fields[['Name', 'Type']]}")
            
            # Compare changed types (same Name but different Type)
            merged = pd.merge(previous_schema, current_schema, on='Name', how='outer', suffixes=('_prev', '_current'))
            changed_types = merged[merged['Type_prev'] != merged['Type_current']]
            if not changed_types.empty:
                print(f"Fields with changed types: \n{changed_types[['Name', 'Type_prev', 'Type_current']]}")
        else:
            print("No previous schema to compare with.")
        
        # Update previous schema to current schema for next iteration
        previous_schema = current_schema[['Name', 'Type']]

# Print the schema evolution
print_schema_evolution(schema_df)
# Out:
# Schema changes for 200901:
# No previous schema to compare with.
#
# Schema changes for 200902:
#
# Schema changes for 200903:
#
# Schema changes for 200904:
#
# Schema changes for 200905:
#
# Schema changes for 200906:
#
# Schema changes for 200907:
#
# Schema changes for 200908:
#
# Schema changes for 200909:
#
# Schema changes for 200910:
#
# Schema changes for 200911:
#
# Schema changes for 200912:
#
# Schema changes for 201001:
# New fields added:
#                    Name        Type
# 216        payment_type  BYTE_ARRAY
# 217         fare_amount      DOUBLE
# 219        total_amount      DOUBLE
# 220          tip_amount      DOUBLE
# 221        tolls_amount      DOUBLE
# 222    dropoff_latitude      DOUBLE
# 224   dropoff_longitude      DOUBLE
# 225    pickup_longitude      DOUBLE
# 226           rate_code  BYTE_ARRAY
# 227           vendor_id  BYTE_ARRAY
# 228     pickup_datetime  BYTE_ARRAY
# 229    dropoff_datetime  BYTE_ARRAY
# 230  store_and_fwd_flag  BYTE_ARRAY
# 231       trip_distance      DOUBLE
# 232     passenger_count       INT64
# 233     pickup_latitude      DOUBLE
# Fields removed:
#                       Name        Type
# 198                End_Lon      DOUBLE
# 199              Tolls_Amt      DOUBLE
# 200                Tip_Amt      DOUBLE
# 203               Fare_Amt      DOUBLE
# 204           Payment_Type  BYTE_ARRAY
# 205                End_Lat      DOUBLE
# 206              Total_Amt      DOUBLE
# 207      store_and_forward      DOUBLE
# 208              Start_Lat      DOUBLE
# 209              Start_Lon      DOUBLE
# 210          Trip_Distance      DOUBLE
# 211        Passenger_Count       INT64
# 212  Trip_Dropoff_DateTime  BYTE_ARRAY
# 213   Trip_Pickup_DateTime  BYTE_ARRAY
# 214            vendor_name  BYTE_ARRAY
# 215              Rate_Code      DOUBLE
# Fields with changed types:
#                      Name   Type_prev Type_current
# 0                 End_Lat      DOUBLE          NaN
# 1                 End_Lon      DOUBLE          NaN
# 2                Fare_Amt      DOUBLE          NaN
# 3         Passenger_Count       INT64          NaN
# 4            Payment_Type  BYTE_ARRAY          NaN
# 5               Rate_Code      DOUBLE          NaN
# 6               Start_Lat      DOUBLE          NaN
# 7               Start_Lon      DOUBLE          NaN
# 8                 Tip_Amt      DOUBLE          NaN
# 9               Tolls_Amt      DOUBLE          NaN
# 10              Total_Amt      DOUBLE          NaN
# 11          Trip_Distance      DOUBLE          NaN
# 12  Trip_Dropoff_DateTime  BYTE_ARRAY          NaN
# 13   Trip_Pickup_DateTime  BYTE_ARRAY          NaN
# 14       dropoff_datetime         NaN   BYTE_ARRAY
# 15       dropoff_latitude         NaN       DOUBLE
# 16      dropoff_longitude         NaN       DOUBLE
# 17            fare_amount         NaN       DOUBLE
# 19        passenger_count         NaN        INT64
# 20           payment_type         NaN   BYTE_ARRAY
# 21        pickup_datetime         NaN   BYTE_ARRAY
# 22        pickup_latitude         NaN       DOUBLE
# 23       pickup_longitude         NaN       DOUBLE
# 24              rate_code         NaN   BYTE_ARRAY
# 25      store_and_forward      DOUBLE          NaN
# 26     store_and_fwd_flag         NaN   BYTE_ARRAY
# 28             tip_amount         NaN       DOUBLE
# 29           tolls_amount         NaN       DOUBLE
# 30           total_amount         NaN       DOUBLE
# 31          trip_distance         NaN       DOUBLE
# 32              vendor_id         NaN   BYTE_ARRAY
# 33            vendor_name  BYTE_ARRAY          NaN
#
# Schema changes for 201002:
# New fields added:
#                   Name   Type
# 234  __index_level_0__  INT64
# Fields with changed types:
#                  Name   Type_prev Type_current
# 0   __index_level_0__         NaN        INT64
# 11          rate_code  BYTE_ARRAY        INT64
#
# Schema changes for 201003:
#
# Schema changes for 201004:
# Fields removed:
#                   Name   Type
# 256  __index_level_0__  INT64
# Fields with changed types:
#                  Name Type_prev Type_current
# 0   __index_level_0__     INT64          NaN
# 11          rate_code     INT64   BYTE_ARRAY
#
# Schema changes for 201005:
#
# Schema changes for 201006:
#
# Schema changes for 201007:
#
# Schema changes for 201008:
#
# Schema changes for 201009:
#
# Schema changes for 201010:
#
# Schema changes for 201011:
#
# Schema changes for 201012:
#
# Schema changes for 201101:
# New fields added:
#                       Name    Type
# 437            airport_fee  DOUBLE
# 439   congestion_surcharge  DOUBLE
# 440                  extra  DOUBLE
# 441  improvement_surcharge  DOUBLE
# 443             RatecodeID   INT64
# 444           DOLocationID   INT64
# 445   tpep_pickup_datetime   INT64
# 446  tpep_dropoff_datetime   INT64
# 448               VendorID   INT64
# 451           PULocationID   INT64
# Fields removed:
#                   Name        Type
# 416  dropoff_longitude      DOUBLE
# 420          surcharge      DOUBLE
# 423   dropoff_latitude      DOUBLE
# 426    pickup_latitude      DOUBLE
# 427   pickup_longitude      DOUBLE
# 430   dropoff_datetime  BYTE_ARRAY
# 431    pickup_datetime  BYTE_ARRAY
# 432          vendor_id  BYTE_ARRAY
# 433          rate_code  BYTE_ARRAY
# Fields with changed types:
#                      Name   Type_prev Type_current
# 0            DOLocationID         NaN        INT64
# 1            PULocationID         NaN        INT64
# 2              RatecodeID         NaN        INT64
# 3                VendorID         NaN        INT64
# 4             airport_fee         NaN       DOUBLE
# 5    congestion_surcharge         NaN       DOUBLE
# 6        dropoff_datetime  BYTE_ARRAY          NaN
# 7        dropoff_latitude      DOUBLE          NaN
# 8       dropoff_longitude      DOUBLE          NaN
# 9                   extra         NaN       DOUBLE
# 11  improvement_surcharge         NaN       DOUBLE
# 14           payment_type  BYTE_ARRAY        INT64
# 15        pickup_datetime  BYTE_ARRAY          NaN
# 16        pickup_latitude      DOUBLE          NaN
# 17       pickup_longitude      DOUBLE          NaN
# 18              rate_code  BYTE_ARRAY          NaN
# 20              surcharge      DOUBLE          NaN
# 24  tpep_dropoff_datetime         NaN        INT64
# 25   tpep_pickup_datetime         NaN        INT64
# 27              vendor_id  BYTE_ARRAY          NaN
#
# Schema changes for 201102:
# Fields with changed types:
#                    Name Type_prev Type_current
# 4           airport_fee    DOUBLE        INT32
# 5  congestion_surcharge    DOUBLE        INT32
#
# Schema changes for 201103:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201104:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge    DOUBLE        INT32
#
# Schema changes for 201105:
#
# Schema changes for 201106:
#
# Schema changes for 201107:
#
# Schema changes for 201108:
#
# Schema changes for 201109:
#
# Schema changes for 201110:
#
# Schema changes for 201111:
#
# Schema changes for 201112:
#
# Schema changes for 201201:
#
# Schema changes for 201202:
#
# Schema changes for 201203:
#
# Schema changes for 201204:
#
# Schema changes for 201205:
#
# Schema changes for 201206:
#
# Schema changes for 201207:
#
# Schema changes for 201208:
#
# Schema changes for 201209:
#
# Schema changes for 201210:
#
# Schema changes for 201211:
#
# Schema changes for 201212:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201301:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge    DOUBLE        INT32
#
# Schema changes for 201302:
#
# Schema changes for 201303:
#
# Schema changes for 201304:
#
# Schema changes for 201305:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201306:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge    DOUBLE        INT32
#
# Schema changes for 201307:
#
# Schema changes for 201308:
#
# Schema changes for 201309:
#
# Schema changes for 201310:
#
# Schema changes for 201311:
#
# Schema changes for 201312:
#
# Schema changes for 201401:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201402:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge    DOUBLE        INT32
#
# Schema changes for 201403:
#
# Schema changes for 201404:
#
# Schema changes for 201405:
#
# Schema changes for 201406:
#
# Schema changes for 201407:
#
# Schema changes for 201408:
# Fields with changed types:
#                     Name Type_prev Type_current
# 8  improvement_surcharge    DOUBLE        INT32
#
# Schema changes for 201409:
# Fields with changed types:
#                     Name Type_prev Type_current
# 8  improvement_surcharge     INT32       DOUBLE
#
# Schema changes for 201410:
#
# Schema changes for 201411:
#
# Schema changes for 201412:
#
# Schema changes for 201501:
#
# Schema changes for 201502:
#
# Schema changes for 201503:
#
# Schema changes for 201504:
#
# Schema changes for 201505:
#
# Schema changes for 201506:
#
# Schema changes for 201507:
#
# Schema changes for 201508:
#
# Schema changes for 201509:
#
# Schema changes for 201510:
#
# Schema changes for 201511:
#
# Schema changes for 201512:
#
# Schema changes for 201601:
#
# Schema changes for 201602:
#
# Schema changes for 201603:
#
# Schema changes for 201604:
#
# Schema changes for 201605:
#
# Schema changes for 201606:
#
# Schema changes for 201607:
#
# Schema changes for 201608:
#
# Schema changes for 201609:
#
# Schema changes for 201610:
#
# Schema changes for 201611:
#
# Schema changes for 201612:
#
# Schema changes for 201701:
#
# Schema changes for 201702:
#
# Schema changes for 201703:
#
# Schema changes for 201704:
#
# Schema changes for 201705:
#
# Schema changes for 201706:
#
# Schema changes for 201707:
#
# Schema changes for 201708:
#
# Schema changes for 201709:
#
# Schema changes for 201710:
#
# Schema changes for 201711:
#
# Schema changes for 201712:
#
# Schema changes for 201801:
# Fields with changed types:
#                    Name Type_prev Type_current
# 4           airport_fee     INT32       DOUBLE
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201802:
# Fields with changed types:
#                    Name Type_prev Type_current
# 4           airport_fee    DOUBLE        INT32
# 5  congestion_surcharge    DOUBLE        INT32
#
# Schema changes for 201803:
#
# Schema changes for 201804:
#
# Schema changes for 201805:
#
# Schema changes for 201806:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201807:
# Fields with changed types:
#                     Name Type_prev Type_current
# 2             RatecodeID     INT64       DOUBLE
# 5   congestion_surcharge    DOUBLE        INT32
# 10       passenger_count     INT64       DOUBLE
#
# Schema changes for 201808:
#
# Schema changes for 201809:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201810:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge    DOUBLE        INT32
#
# Schema changes for 201811:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201812:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge    DOUBLE        INT32
#
# Schema changes for 201901:
# Fields with changed types:
#                    Name Type_prev Type_current
# 5  congestion_surcharge     INT32       DOUBLE
#
# Schema changes for 201902:
#
# Schema changes for 201903:
#
# Schema changes for 201904:
#
# Schema changes for 201905:
#
# Schema changes for 201906:
#
# Schema changes for 201907:
#
# Schema changes for 201908:
#
# Schema changes for 201909:
#
# Schema changes for 201910:
#
# Schema changes for 201911:
#
# Schema changes for 201912:
#
# Schema changes for 202001:
#
# Schema changes for 202002:
#
# Schema changes for 202003:
#
# Schema changes for 202004:
#
# Schema changes for 202005:
#
# Schema changes for 202006:
#
# Schema changes for 202007:
#
# Schema changes for 202008:
# Fields with changed types:
#           Name Type_prev Type_current
# 4  airport_fee     INT32       DOUBLE
#
# Schema changes for 202009:
#
# Schema changes for 202010:
# Fields with changed types:
#           Name Type_prev Type_current
# 4  airport_fee    DOUBLE        INT32
#
# Schema changes for 202011:
# Fields with changed types:
#           Name Type_prev Type_current
# 4  airport_fee     INT32       DOUBLE
#
# Schema changes for 202012:
#
# Schema changes for 202101:
#
# Schema changes for 202102:
#
# Schema changes for 202103:
#
# Schema changes for 202104:
#
# Schema changes for 202105:
#
# Schema changes for 202106:
#
# Schema changes for 202107:
#
# Schema changes for 202108:
#
# Schema changes for 202109:
#
# Schema changes for 202110:
#
# Schema changes for 202111:
#
# Schema changes for 202112:
#
# Schema changes for 202201:
#
# Schema changes for 202202:
#
# Schema changes for 202203:
#
# Schema changes for 202204:
#
# Schema changes for 202205:
#
# Schema changes for 202206:
#
# Schema changes for 202207:
#
# Schema changes for 202208:
#
# Schema changes for 202209:
#
# Schema changes for 202210:
#
# Schema changes for 202211:
#
# Schema changes for 202212:
#
# Schema changes for 202301:
#
# Schema changes for 202302:
# New fields added:
#              Name    Type
# 3198  Airport_fee  DOUBLE
# Fields removed:
#              Name    Type
# 3178  airport_fee  DOUBLE
# Fields with changed types:
#                Name Type_prev Type_current
# 0       Airport_fee       NaN       DOUBLE
# 1      DOLocationID     INT64        INT32
# 2      PULocationID     INT64        INT32
# 3        RatecodeID    DOUBLE        INT64
# 4          VendorID     INT64        INT32
# 5       airport_fee    DOUBLE          NaN
# 11  passenger_count    DOUBLE        INT64
#
# Schema changes for 202303:
#
# Schema changes for 202304:
#
# Schema changes for 202305:
#
# Schema changes for 202306:
#
# Schema changes for 202307:
#
# Schema changes for 202308:
#
# Schema changes for 202309:
#
# Schema changes for 202310:
#
# Schema changes for 202311:
#
# Schema changes for 202312:
#
# Schema changes for 202401:
#
# Schema changes for 202402:
#
# Schema changes for 202403:
#
# Schema changes for 202404:
#
# Schema changes for 202405:
#
# Schema changes for 202406:
#
# Schema changes for 202407:
#
# Schema changes for 202408:
